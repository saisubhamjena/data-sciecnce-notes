# %% [markdown]
# <a href="https://colab.research.google.com/github/saisubhamjena/data-sciecnce-notes/blob/main/Bokeh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
pip install bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

p=output_file('test.htmt')

p=figure(title='Flower')
p.xaxis.axis_label='petal length'
p.yaxis.axis_label='petal width'

p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="a2820c50-4821-4de3-bfa0-d2dda039074c" data-root-id="1255"></div>

# %%
p=output_file('line.htmt')

p=figure(title='Line Graph')
p.xaxis.axis_label='x-axis'
p.yaxis.axis_label='y-axis'

p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="a3bbf1e6-00ba-41c6-adc6-764a8dab771a" data-root-id="1505"></div>

# %%
x=[1,2,3,4,5]
y=[3,4,5,6,7]

output_file('line.html')
p=figure(title='Line Plot')
p.scatter(x,y, fill_color='red',size=20)
show(p)
# Out:
#   <div class="bk-root" id="3a6d3901-d20d-4b1e-99f3-5372450bf380" data-root-id="2385"></div>
